# %%
#imports of libraries of both webscraping billboards hot100 and spotify api
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# billboard hot 100
url = 'https://www.billboard.com/charts/hot-100/'
response = requests.get(url)
soup = BeautifulSoup(response.content)

# %%
#soup.select("h3.a-no-trucate")[0].get_text(strip=True) get first title
#soup.select("span.c-label.a-no-trucate")[0].get_text(strip=True) get first author

#hot100_dict = {"title": [], "author": []}
title_list = []
artist_list = []
for i in range(99):
    title_list.append(soup.select("h3.a-no-trucate")[i].get_text(strip=True))
    artist_list.append(soup.select("span.c-label.a-no-trucate")[i].get_text(strip=True))

#title_list, author_list check to works: works

# %%
bb_df = pd.DataFrame({'title': title_list, 'artist': author_list})
bb_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bb_df = pd.DataFrame({'title': title_list, 'artist': author_list})
#       2 bb_df
#
# NameError: name 'author_list' is not defined

# %%
song_entered = input('Please enter your favourite song and artist like this example: "mensch","herbert groenemeyer"')
# Correct usage with split and strip
song_artist_input = [item.strip().strip('"').lower() for item in song_entered.split(',')]
song_artist_input
# Out:
# Please enter your favourite song and artist like this example: "mensch","herbert groenemeyer" zeit dass sich was dreht
# ['zeit dass sich was dreht']

# %%
from difflib import SequenceMatcher
import numpy as np
threshold_song = 0.7
threshold_artist = 0.5

song_entered = input('Please enter your favourite song and artist like this example: "mensch","herbert groenemeyer"')
# Correct usage with split and strip
song_artist_input = [item.strip().strip('"').lower() for item in song_entered.split(',')]

match_found = False
for title in bb_df['title']:
    similarity = SequenceMatcher(None, song_artist_input[0], title.lower()).ratio()
    if similarity >= threshold_song:
        for artist in bb_df['artist']:
            similarity = SequenceMatcher(None, song_artist_input[1], artist.lower()).ratio()
            if similarity >= threshold_author:
                if input(f'Match found: {title} by {artist}. Did you mean this song? Type "yes" or "no".') == "yes":
                    # Get random row and column indices
                    random_row = np.random.randint(0, bb_df.shape[0])
                    random_title = bb_df.iloc[random_row, 0]
                    random_artist = bb_df.iloc[random_row, 1]
                    print(f'Your randomly selected song: {random_title} by {random_artist}')
                    match_found = True
                    break
        if match_found:
            break
else:
    print("No match found")
# Out:
# Please enter your favourite song and artist like this example: "mensch","herbert groenemeyer" A bar song,shabozey
# Match found: A Bar Song (Tipsy) by Shaboozey. Did you mean this song? Type "yes" or "no". y
# Match found: A Bar Song (Tipsy) by Hozier. Did you mean this song? Type "yes" or "no". yes
# Your randomly selected song: Hey Jane by Tyler, The Creator

# %%
# spotify api (tuesday)
#Initialize SpotiPy with user credentials
from config import client_id, client_secret
import spotipy
import pandas as pd
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
#idea: iterate over spotify genres for 
#len(sp.recommendation_genre_seeds()['genres']) #126 genres in spotify
#sp.recommendation_genre_seeds()['genres']
sp.recommendation_genre_seeds()
#126 genres: 30 songs per genre in the final dictionary = 3780 songs
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %%
import time
import json
import os
import random

songs_data_file = "songs_data.json"
completed_genres_file = "completed_genres.json"

# Load checkpoints if they exist
if os.path.exists(songs_data_file):
    with open(songs_data_file, "r") as f:
        songs_data = json.load(f)
else:
    songs_data = {}

if os.path.exists(completed_genres_file):
    with open(completed_genres_file, "r") as f:
        completed_genres = set(json.load(f))
else:
    completed_genres = set()

# Fetch available genres
available_genres = sp.recommendation_genre_seeds()['genres']

# Skip already completed genres
remaining_genres = [genre for genre in available_genres if genre not in completed_genres]
print(f"Genres to process: {remaining_genres}")

# Target: Collect songs for each genre
for genre in remaining_genres:
    print(f"\nStarting collection for genre: {genre}")
    genre_songs = set()  # Track unique songs for this genre

    try:
        # Single API call: Fetch up to 50 tracks
        recommendation_results = sp.recommendations(seed_genres=[genre], limit=42)

        # Sort tracks by popularity
        sorted_tracks = sorted(recommendation_results['tracks'], key=lambda x: x['popularity'], reverse=True)
        
        # Top 15 most popular songs
        popular_tracks = sorted_tracks[:15]

        # Remaining tracks (not in the top 15)
        remaining_tracks = sorted_tracks[15:]

        # Randomly sample 15 tracks from the remaining songs
        random_tracks = random.sample(remaining_tracks, min(15, len(remaining_tracks)))

        # Add the popular tracks to the dataset
        for track in popular_tracks:
            song_id = track['id']
            if song_id not in songs_data:
                songs_data[song_id] = {
                    'id': song_id,
                    'name': track['name'],
                    'artist': [artist['name'] for artist in track['artists']],
                    'genre': genre,
                    'popularity': track['popularity']
                }
                genre_songs.add(song_id)

        # Add the random tracks to the dataset
        for track in random_tracks:
            song_id = track['id']
            if song_id not in songs_data:
                songs_data[song_id] = {
                    'id': song_id,
                    'name': track['name'],
                    'artist': [artist['name'] for artist in track['artists']],
                    'genre': genre,
                    'popularity': track['popularity']
                }
                genre_songs.add(song_id)

    except Exception as e:
        print(f"Error fetching tracks for genre '{genre}': {e}")

    print(f"Finished collecting for genre '{genre}': {len(genre_songs)} songs collected.")

    # Save progress to checkpoint files
    completed_genres.add(genre)
    with open(songs_data_file, "w") as f:
        json.dump(songs_data, f)
    with open(completed_genres_file, "w") as f:
        json.dump(list(completed_genres), f)

    # Rate limiting
    time.sleep(5)

print(f"\nTotal unique songs collected: {len(songs_data)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 23
#      20     completed_genres = set()
#      22 # Fetch available genres
# ---> 23 available_genres = sp.recommendation_genre_seeds()['genres']
#      25 # Skip already completed genres
#      26 remaining_genres = [genre for genre in available_genres if genre not in completed_genres]
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:1733, in Spotify.recommendation_genre_seeds(self)
#    1730 def recommendation_genre_seeds(self):
#    1731     """ Get a list of genres available for the recommendations function.
#    1732     """
# -> 1733     return self._get("recommendations/available-genre-seeds")
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     266 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     267              method, url, args.get("params"), headers, args.get('data'))
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#     276     results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     939     return response
#     941 response.drain_conn()
# --> 942 retries.sleep(response)
#     943 log.debug("Retry: %s", url)
#     944 return self.urlopen(
#     945     method,
#     946     url,
#    (...)
#     959     **response_kw,
#     960 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:359, in Retry.sleep(self, response)
#     350 """Sleep between retry attempts.
#     351
#     352 This method will respect a server's ``Retry-After`` response header
#    (...)
#     355 this method will return immediately.
#     356 """
#     358 if self.respect_retry_after_header and response:
# --> 359     slept = self.sleep_for_retry(response)
#     360     if slept:
#     361         return
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:338, in Retry.sleep_for_retry(self, response)
#     336 retry_after = self.get_retry_after(response)
#     337 if retry_after:
# --> 338     time.sleep(retry_after)
#     339     return True
#     341 return False
#
# KeyboardInterrupt:

# %%
songs_df = pd.read_json('songs_data.json', orient='index')
songs_df = songs_df.reset_index(drop=True)
songs_df
# Out:
#                           id                                name  \
# 0     4JjPLqECP5E48MXcEc2wzA                        Tainted Love
# 1     2ihCaVdNZmnHZWt0fvAM7B                        Little Talks
# 2     37928J06bQreiIuhZvRlWQ                 When the Lights Die
# 3     6ERQqdIkr7Rp4tt52Eep6r                    The Look Of Love
# 4     6WVtfUA8r0iYmQotCRVp2J                    Bette Davis Eyes
# ...                      ...                                 ...
# 3558  7tKHQy1vQGRHL9mIt5biX3      Im Tachpetza (If Thou Wisheth)
# 3559  6ooW7AxiD8FRyIBwVFKC6X                     El Son te Llama
# 3560  1qetiiwkJuzkL91TnzBJ9R                           La drogue
# 3561  7FIKMHuZDDlAx0j8wccvFj                               Gomni
# 3562  6O3cgvwRrl0Nv48diMuelA  Panaderos Flamencos - Instrumental
#
#                                     artist        genre  popularity
# 0     [Stella Starlight Trio, Karen Souza]     acoustic          35
# 1                    [Of Monsters and Men]     acoustic          77
# 2                           [Boyce Avenue]     acoustic          15
# 3                            [Diana Krall]     acoustic           0
# 4           [Jazzystics feat. Karen Souza]     acoustic           0
# ...                                    ...          ...         ...
# 3558                        [Idan Raichel]  world-music           0
# 3559                    [Orchestra Baobab]  world-music           0
# 3560                     [Ali Farka Touré]  world-music           0
# 3561    [Ali Farka Touré, Toumani Diabaté]  world-music           0
# 3562                       [Paco de Lucía]  world-music           0
#
# [3563 rows x 5 columns]

# %%
songs_df[songs_df['popularity'] > 80]
# Out:
#                           id                              name  \
# 11    3U4isOIWM3VvDubwSI3y7a                         All of Me
# 359   6nek1Nin9q48AVZcWs9e9D                          Paradise
# 448   1gihuPhrLraKYrJMAEONyc        Feel So Close - Radio Edit
# 478   0I3q5fE6wg7LIfHGngUTnV                       Ms. Jackson
# 479   0BCPKOYdS2jbQ8iyB56Zns                            Clocks
# 777   5rb9QrpfcKFHM1EUbSIurX  Yeah! (feat. Lil Jon & Ludacris)
# 778   55h7vJchibLdUkxdlX3fK7                          Treasure
# 999   5xEM5hIgJ1jjgcEBfpkt2F                       Complicated
# 1378  2374M0fQpWi3dLnB54qaLX                            Africa
# 1520  6gBFPUFcJLzWGx4lenP6h2                        goosebumps
# 1722  7w87IxuO7BDcJ3YUqCyMTT                   Pumped Up Kicks
# 2470  3XVBdLihbNbxUwZosxcGuJ                If I Ain't Got You
# 2497  4nVBt6MZDDP6tRVdQTgxJg                  Story of My Life
# 2498  0tgVpDi06FyKpA1z0VMD4v                           Perfect
# 2499  1QV6tiMFM6fSOKOGLMHYYg                        Poker Face
# 2833  34gCuhDGsG4bRPIf9bb02f                 Thinking out Loud
# 2939  1mea3bSkSGXuIRvnydlB5b                      Viva La Vida
# 3358  2WfaOiMkCvy7F5fcp2zZ8L                        Take on Me
# 3459  0d28khcov6AiegSCpG5TuT                    Feel Good Inc.
# 3487  0ntQJM78wzOLVeCUAW7Y45                       Sex on Fire
#
#                           artist      genre  popularity
# 11                 [John Legend]   acoustic          83
# 359                   [Coldplay]    british          81
# 448              [Calvin Harris]   children          82
# 478                    [Outkast]      chill          81
# 479                   [Coldplay]      chill          81
# 777   [USHER, Lil Jon, Ludacris]      disco          84
# 778                 [Bruno Mars]      disco          82
# 999              [Avril Lavigne]        emo          81
# 1378                      [TOTO]      happy          83
# 1520              [Travis Scott]    hip-hop          85
# 1722         [Foster The People]  indie-pop          84
# 2470               [Alicia Keys]      piano          81
# 2497             [One Direction]        pop          87
# 2498                [Ed Sheeran]        pop          86
# 2499                 [Lady Gaga]        pop          81
# 2833                [Ed Sheeran]  road-trip          81
# 2939                  [Coldplay]    romance          85
# 3358                      [a-ha]  synth-pop          84
# 3459                  [Gorillaz]   trip-hop          84
# 3487             [Kings of Leon]    turkish          82

# %%
list_of_songs_id = songs_df['id'].to_list()
print(len(list_of_songs_id))
list_of_songs_id
# Out:
# 3563
# ['4JjPLqECP5E48MXcEc2wzA',
#  '2ihCaVdNZmnHZWt0fvAM7B',
#  '37928J06bQreiIuhZvRlWQ',
#  '6ERQqdIkr7Rp4tt52Eep6r',
#  '6WVtfUA8r0iYmQotCRVp2J',
#  '70zapGEw5KQiHBhjNcGjzo',
#  '76aadnUFFANRNDs6L3aqxw',
#  '6J7cSyvSCnPwv3vqHchEfL',
#  '7iBSkXB0pTvZasOLf0Qxk9',
#  '2nGFzvICaeEWjIrBrL2RAx',
#  '2BBb3UMJBNlofpC25pbSp4',
#  '3U4isOIWM3VvDubwSI3y7a',
#  '7bcP9k51f1VNCaFUyZ3P5M',
#  '6Vc5wAMmXdKIAM7WUoEb7N',
#  '0SuG9kyzGRpDqrCWtgD6Lq',
#  '3GKZKaNY0Stt4swaxz83E5',
#  '33e9HtOfO1ye1h8xQ7Foc9',
#  '4eiWWDbWczW2GLqg6Lyg48',
#  '2yBAPa9HZj3P2szSaaj4k1',
#  '6qTmjG7thRJEOaUKFmfjGR',
#  '6N001s7hglDhXJyjeXeg4F',
#  '4vojpVoYaj4myAkIcfNKIN',
#  '08kTO4EW0jb07zNsCNM83w',
#  '3LHg768dEKqJKht2uPTlVR',
#  '2Gb3up6s243JSVuRRjwQoF',
#  '5jclmAX2XQp5G3b6K30UJl',
#  '1xcxzCeF86LD3mFh36Ou4S',
#  '6wZI4mdT8JwXgkGURnBQiq',
#  '6rzWV1cY3OQLR4as5NcTEd',
#  '7bcHBD27hxkK5aSXjWOysM',
#  '1mDZpgKx9Xpg6ijl9DvdA6',
#  '4Xjtbdoc3Y5V4O4hM9bUsF',
#  '7ha7zYOryB0rpnMTa4S75U',
#  '7sWqtUHJqs6T9926ygd52v',
#  '1rVyxy6CRo3dB5z5oNKZfc',
#  '68RV0HNYnbkrztSe9sBZ1W',
#  '37BTh5g05cxBIRYMbw8g2T',
#  '6i2YA4WM3FqwyO7UX7XWbx',
#  '0RmXtDH1cBMGImRrmn5xL6',
#  '3N4gUEMXtxvDhPo5ifI5uX',
#  '5ipni5g3JBMmFwWcUvIfFR',
#  '4M90HjffovjuEZS0LdlIks',
#  '7Hv89f7Dpm5Hce1XkBbjQZ',
#  '3HpqoffTzMozYYZru9qapf',
#  '4jvfzleLDS7kAcCzBurkQn',
#  '4TLGUA3N47qYyl4rdNkTFG',
#  '2bWs6hFVGp5YvDYCW1pW0Z',
#  '2wEKd4l4zJDfDFIxqDqex7',
#  '4d4mfz1H6PsC9QPr1w8rfD',
#  '4AVIdds2A4E4UsZcVU0Uso',
#  '0yfeyqPCZrkyC3hxb6ycIH',
#  '2FgVxc84fG0OQr7v11cloX',
#  '2QFOiuWaOnq98fLE764PfX',
#  '7vPKfwEsnAI5vVtuKQXK8l',
#  '6MBZHOilZfNn5cVNRYXjVT',
#  '2U4kPiipwfc2oHmd0nGoj5',
#  '2eepRxzqOynKv8WObUtfTa',
#  '42JAo0oBbu9ZNRTPgBxG8H',
#  '1R2SZUOGJqqBiLuvwKOT2Y',
#  '4ASD9pZQe6T1lwNfgIQTFT',
#  '2YfhATomatu6KrkowVceuR',
#  '0XRoKzH7h7lhlm1DzqleqC',
#  '3I9ShIr2hAM9MjEdjBC0Eu',
#  '2toY6JyyfKy9TwNk3Ou2XG',
#  '4VQcmzxaGAJRHufuiLxCAe',
#  '4pkFvX3AkuiSGPkv8gMlks',
#  '4uUOkgfRZNelqua7IR5yOC',
#  '7c1Dar0pIAW7w5TzaGjt9t',
#  '7FhBSLKkjTFTcqsnDFye9d',
#  '6XUuSvFmYeoFCqNsGaedCZ',
#  '4m1cUjNq5ptDQ5TN9ce9QH',
#  '3YuaBvuZqcwN3CEAyyoaei',
#  '60IMjTxu5reUpuhuZcdgVA',
#  '0Jv0PJz6LZdCygPsFnML3a',
#  '1xNhYOLcGR14v5JJLe7aaZ',
#  '1EiKmk4AwuNG2CmhQcCJ8k',
#  '5uDqT9eP1Jfdf7e2p6VIGt',
#  '3JRas7vmV7l3rjtQYNcLDN',
#  '5Wom2duXOmf0RzOG9c27QZ',
#  '5fxfwjQ1OmbnkOlg39HsSO',
#  '3672j9qcUufXuGwVoXHaeK',
#  '5XXpZ7TZjkQLEr36ba4HEY',
#  '3Xs2N8U8Zf1e45PnExkPTy',
#  '6I4vrVjeJn5z8CE8anblST',
#  '4Tw53Ljw0JuQIGH0aJq9Zb',
#  '3G0kzHUQGkhgWurrYEOQKd',
#  '1AfYo6cKm3yHsJHdmNoGO1',
#  '0tSSoikrj4Gprv5IEqCVlU',
#  '1zOe3hc0NEaynHhXGZq83I',
#  '5Lhwnf8QEeC1gO7eXT7AUw',
#  '3FtYbEfBqAlGO46NUDQSAt',
#  '2Foc5Q5nqNiosCNqttzHof',
#  '5VGlqQANWDKJFl0MBG3sg2',
#  '0a7BloCiNzLDD9qSQHh5m7',
#  '5Fli1xRi01bvCjsZvKWro0',
#  '1fBl642IhJOE5U319Gy2Go',
#  '50Re2bLgXqG9qN7v2QHNTm',
#  '2oSpQ7QtIKTNFfA08Cy0ku',
#  '0OYcEfskah1egYHjYRvbg1',
#  '76Je5Wklky23mVoxiRszcN',
#  '6ISuXA3UCPMtsyEUGUTAyn',
#  '57nNNkgk768QVXq3uHxu5e',
#  '23NPGXlSaIqWzvxIRhM2oG',
#  '32fmQsWSAaDas2MJRyMSGG',
#  '6HFbq7cewJ7rPiffV0ciil',
#  '2aCsRmHTuWPL7WnL5uSijc',
#  '0jjphpegPbJIk0C6BSvTE5',
#  '3OtpZhuI28h9yDjDbOkqSb',
#  '5ujavRJ7Mdjg8IEUoWlLCo',
#  '53Pgsvu3qSYO2aXt5J2vcL',
#  '7JNzuzPA578kryw1T49Nw2',
#  '07bEZWP1PqS5jCR0iiz1zt',
#  '1kUmkp42FTNSl5bZmjj5Xq',
#  '4V05j7HDUU2bZQwDOeIySh',
#  '2xwedMsRwKEtLos3oN5pt9',
#  '2UE4m8egf0aREmOi47sDOk',
#  '3HfB5hBU0dmBt8T0iCmH42',
#  '7C6NcqS3fNDXLgP5L2Kbgp',
#  '03wKMRNYVvw6s9nm4I4jUS',
#  '3M9mw3BfQpHkrhUbOEnaAg',
#  '40UlFC0dIxv7lAEJaPZLnm',
#  '3WS7spXVlbeC5kjePmHMQW',
#  '2pr6us08iPNzIex5q6fMvI',
#  '50mwGp3PgKoZldhBvfy2cf',
#  '5z0QLEpkbUh00SevSuYxOh',
#  '2jw4JU0wJkNWURreYQsblk',
#  '3OgkfYg13Jj96E982moWje',
#  '19i0eqVS2lrRToPje5e6Rg',
#  '41RiTUEXw8uoCtLd8pcHVy',
#  '5pAR56gg3tYThEeH0VM3iB',
#  '7enRMTKnzaeYQsBgRYmCle',
#  '25N6tLYS1uFJ3c5lsXV3y1',
#  '1LDQpmzXg5ZFfdqdBQFw03',
#  '7yoQyZXnpRbh7k78dzWO00',
#  '0MSEhfQE0256xTKHtaNkXB',
#  '2UKYMN7VnsQo40n0qCt6Sa',
#  '5KLZDzUwTvJmNV3t5bjBCs',
#  '2fvad0h6zooi0XDoNEJr3R',
#  '5pIVFUFslPrfHlGsgAboE4',
#  '4owSUnc0zWYZQ6VWcjYd31',
#  '3aSi0UcesbPx5ADnOqxkrr',
#  '37IwDzmSZXEZcER596VF3w',
#  '5YdmA6bqwLXgQq7XmSfJcC',
#  '4n2VYfRqGksjp2rfsC5xW5',
#  '5QIkWpgfZHlhUBI099FWnC',
#  '0GU7HXMGewpD83cGv6a5YH',
#  '2XQSgmtEY2titXhfY414dy',
#  '4MYjbvSyqOGWXZBGRHVRtU',
#  '2Lx9qpN7NgiWD4rgSQRBGH',
#  '3uS2P07FDjhm1GlXKWKilM',
#  '6OKHlCt9rRE0Fe9S7r8hgN',
#  '2jgVyvvBfdf6LC1EUSYDDM',
#  '5SESuzrqsIPYQGVSAQMe9e',
#  '1HMLbvDbyfniV76H5EUF76',
#  '3Wi938kzYryCUQLAobDe1B',
#  '6ugtUW5ATAKM3FtM9qdh7F',
#  '3q6Rqbhv4ta78QwrMKA5dX',
#  '4xvfH6Gl07mbwK0lCjt8lD',
#  '1Kb08Fv8MxNkOzWzXmx7n8',
#  '2DduLyMo7AvEkneIBpXkie',
#  '6vQsQ7ULyCpitOxV1d5MIQ',
#  '16cVPyNOv2QQaD5V6WMlZw',
#  '3v605eHNKw2umT3UiXJggt',
#  '4tsEtjUVBFLT2pMDVlCHoQ',
#  '2Jgpo5dmdKz2BdCFTFCEKO',
#  '3fP9JI6dKVJ9n0V3j0XAzp',
#  '3hquJk6uKZ2lxmkwPx4U2P',
#  '467tO3ADQs6m3I6rXMTKUJ',
#  '4r6C7r5F2UiE7AI8I4PG1y',
#  '7pcJFLafB3isSYiqwMD48r',
#  '74zUgoDZNldMznNriKRa3N',
#  '2BfxDQgxWAH2I0xGMFzmnr',
#  '0K4ALEmDAuDgwouoeZ1cGs',
#  '3U7EHMXg21hYDJrywfPkBq',
#  '4gJrYv7pMjwvYeVxxVtOqg',
#  '4BhbfycCOolFAy811R7yni',
#  '3XrXJYQ7PmunKYET01u0v2',
#  '5RsRhryZD9FdTmxsAaZ2mM',
#  '0ferOfb9ppCVtlsOcl5BqJ',
#  '5anTq92Q9ldtCPcsp6rysC',
#  '14JG4VbsqeLsFuDJlkybOT',
#  '1hMvlPP5B2VNdQkoyPG7Df',
#  '6Qk0gW5M6kRmFycEjAUiLK',
#  '0sTJIm208qovTP0zLp9Ih5',
#  '18NypWmoW8PMQCcfWUV913',
#  '0uysqXykfblDEQyIKgcLdq',
#  '5uhp4ISSziyxrebEcDrGce',
#  '1sQaSAqIhnTBpMLsyZjjOH',
#  '4hMx0vKP14GYJhYJz8IhTa',
#  '3K4oTnstzaP6bcXVksdaxe',
#  '50O2iekXfaJMDHzhF2nHCN',
#  '2HNL6gVAd6r85JKTcDsCUu',
#  '4rN6FwvfTuU7dr8SPPDVK1',
#  '5yjh3L50uTieKFyvIc9ioc',
#  '1gHNs02MsCvMhgSl9GWJsf',
#  '0hnINRVnDhz8PHrJwKZlYl',
#  '6eZ36FW9lkfYsTwr1Bje9p',
#  '5JQJFtmq1NxX1hTFfLg4TT',
#  '5tXdsbPCOEZqnuOA0uTNsK',
#  '57yZkQamv9AQKCCWsNDPIn',
#  '0c3DVFD95vKGM5eYyACR5W',
#  '0pq1WStnwZS06YSh8ANBeo',
#  '0p7biAwTesVvMG2oUZbu7l',
#  '2hPpUDME59THtvTZHPyxgR',
#  '0CSnzEZnVddmquNlVrdjTD',
#  '65ctx4YGWEn3QDYrxSSAoo',
#  '4bCePthvrPb9hWHtEQuepn',
#  '4FvbgKhTYHGdjJkusfma8D',
#  '1nnTwytRue0ldVrMIfXtxB',
#  '4HJZmcBxQ7eeYfNDX8dVDV',
#  '26uHwSHlaK5mskSMhbRod3',
#  '5LfDOTMc5zVt3RLvLkme3L',
#  '71aoPq0Cez3dtsSMXJHqXI',
#  '0l4s9ze0CrQfOiE8jaMs1H',
#  '3oSdxIGuxOHZ7pTNKKXGDb',
#  '6TI4HKSi6GpMeq2vpkInSk',
#  '1BrS9cy4zHpXYq9oVYQJF5',
#  '19NzE5g2N3SnQSj2chLetU',
#  '0FngZC9wJx2CPJIusVNYPh',
#  '6gO8eiM6KxZeTNzZAS14Tb',
#  '490VPBUaXlSqNM0y5zP7H5',
#  '7eT5uQWbQ7l2BmCSlsqUsQ',
#  '4NgHCEYBTA4ZzYa2tzOYyy',
#  '0kvy8rEXxfiVBAmBpRqJrU',
#  '1ZkurUyIfW1wESFJp7GXgK',
#  '6lYTWKKrSalqfCUyAwUI0Y',
#  '1gCzS6LuqFWPFD0UE1bINb',
#  '2uwdw8W9DiZCf9pQHPOVvz',
#  '3hF7gCSBoshG3GHUUV8otI',
#  '2iXdi6IgLOBY33dee0CQYX',
#  '4xMmjrefx4NlEOHfGu3EQf',
#  '0pEGMW8o4oCCD8yVN39yZj',
#  '1KxLzB9KVb51oJYdqYu9Cv',
#  '2Eds5hWb1ABDkii1XFTe3R',
#  '6fuXJKtwETEgdLqu9gvuDv',
#  '3wsZYuHJrk3lssa7V7jvye',
#  '2P6K6eqmlhUgSZAi6MRem6',
#  '6vFyvgTxOrf0Xg07WKlzkB',
#  '2CneZudVYQBFTVxOkDF2Rn',
#  '1x2zQ4k5dK0oLI2cPnxuq3',
#  '2jdAk8ATWIL3dwT47XpRfu',
#  '3SktMqZmo3M9zbB7oKMIF7',
#  '4LloVtxNZpeh7q7xdi1DQc',
#  '7GRq9NUgqhxPGUUksX02fk',
#  '6rtIf2peTj5KMl7o6G0ldg',
#  '1nwXca4jNGWDpowRQnEiEv',
#  '4hnLubxViF8ScCBBWHUGGP',
#  '47GPlXb3Zhg0UarP3qKQjP',
#  '0c42JkNYZzZTNVWJvIuaRm',
#  '4e03J3XTZ9SZMlbZ1RhgiK',
#  '63vJRHgZyFTMUaMtkdiD2g',
#  '3MCRz5li4Sp6SKfz2tqxn0',
#  '3fQROsblXAovEB4aZcer3w',
#  '6raKumUf0iCaBRZWG25KY2',
#  '6qrnUwHfWubFB8tdvrAsby',
#  '7CxPQyJOYF2LSprk6iPDmX',
#  '7raDFRvIHLFg9FLku963xk',
#  '3WeWCiniWbZD4FCPuy3qQu',
#  '5C9tyGpGGXKUElCmzMUWz1',
#  '3ZtItXu2ypXh5ltAfnpVIV',
#  '50yVEqOnLHtRTHWq3PWBuZ',
#  '618hiI74zBL8UVgAvfmkLj',
#  '0Cvjlph1WGbwZY1PlMEtJY',
#  '7egyR1d4Xmr1TsmpJct9bL',
#  '4mGVChT7up6vHHFj4gLJUM',
#  '6m9aTQU6eMX3ZXzCV3PRKk',
#  '33fdvicpRVPWCPz19Obajn',
#  '0OXd5YAycHH6Jc3KvZvc4X',
#  '0tsKu0o04uNgkXpP8mP6tQ',
#  '1TyCTyCab7MMTadRWoXYbT',
#  '4ipc1Wpcj2IBhLJCCAKgBg',
#  '7crW4JI0pCXpD8megZliLS',
#  '6b4ZEmY1fWYXdaZCfKmFZv',
#  '4jLIEXcCB5jeo66t53tP4f',
#  '3pMmRPF5PK5r3RdfAS7nIc',
#  '6G7Si9hoDxLKZRmtosfZ2L',
#  '3UQuQ2eL2qVvLQGDO6DXin',
#  '4SvrcCGSJrWlryWbPNUNML',
#  '22qkgKaLMCCG7HKhzfBm6k',
#  '3Wku87vvflwDHFuzN2OFAa',
#  '34qsj3eFSrApDeLxeZfW2D',
#  '29SLeqMkWGFXOHnhf44nKN',
#  '6QiVClgRjKvqXDlH2zhhGB',
#  '4CtNZVKo9fOxlWDmDdMhQQ',
#  '3vfTZJNAR9zqZfqqJSpo2j',
#  '4mdnsQW0Ryxx31Vqy2dE6Z',
#  '2P0nOcYl6xEjj39yo5R6BA',
#  '3EIGWioextpJQBR6XBBRxo',
#  '5DhPzSIi0HHZNJOOwIy3Xn',
#  '6dvNnlBj8DQEQE8YiqmccO',
#  '1VDUpOeHQJHm7k1vGZe9F0',
#  '6d3hPBLKPke9Pn00QffgMs',
#  '3sjbgAK6gvceFhatwLgPG0',
#  '3aJ2jrhLVDxhYO6eopAOdK',
#  '4OGx2EAXeR2it0ZPUveuip',
#  '67snFUC6Jfl8fKgskGQrmH',
#  '2fNREKcsUJbp62WefiOwzB',
#  '7240PkTnUTQq5nEgyUxeyJ',
#  '5ObbENesRKdAzkvvPXrSM7',
#  '5vVmSFSzXfon0FonU1MtgB',
#  '7MnT7msJZg3XBAS0OTfGrB',
#  '1Tditr5KyzStSK3GiO6Xlj',
#  '0PgsB53yhlKs8D19LgYU4i',
#  '7ATfTQCF4OGSY91yKk42km',
#  '5yFI0Vs3x4EbeIDerT0ck1',
#  '2yQMmtem48vOjB1OXAvbKD',
#  '2ma8V5vEOfCuyqZ0V8HAq3',
#  '28aUFtkMnJaqNQkLHR0weV',
#  '1eDBpkZgY7p9OBVodcrX9n',
#  '266WEiJhZI1dNUcOqr7Yzi',
#  '6zBw2Qqqj2daIoST9XIJC4',
#  '1aUUrBmdIYN7FvIzHdpisn',
#  '2kYAcKRS0NIhMJbHjyMEkZ',
#  '1LR5KBD64oRzGEjQhAMNdj',
#  '0q1hmhVWdR04mZup6mR56u',
#  '0nppnJpYfTBwW7WpnQXlB3',
#  '2WayN4wXOseclKADq2tFTY',
#  '0JUdM6lKJafF1ucVO3PgBK',
#  '1BGrHLBKZCVGslxe0dSExv',
#  '1Ly6VdODSs8qXcqok09EJt',
#  '0EX0wy0g1amU55KWD9Kovf',
#  '7ieOQPT3n26Hav7QtTSGR4',
#  '3o9QS7tLm7YskEG7NWbpcz',
#  '6q042pQaILWdtxJxbf0jXj',
#  '14zHULg93hiSpMR71IzMs3',
#  '5Z29IzMEP5TY8HsXWwPYWX',
#  '0UtoASDXmEeZklHfKlqz8s',
#  '6mOdAPdACSVkUIyaRPjkAv',
#  '3Pssl5CAjQVYMJDlPphGUb',
#  '4Z8zmUkhtz6pCLuWEUFx4J',
#  '6ZOeDXutLpSGqA1sSL6LrL',
#  '7G4U7IDXXPz1PFlKpfDGoZ',
#  '1TdfRFmp4z1h2ecflxCaV3',
#  '7inW3Cs2l4laNgLKp5R17K',
#  '1r1OeKQ1y7Q20A6ekUXtYq',
#  '7Lny0czH9uuoW2drDO9xvh',
#  '1MbarPuZfaWLUWtCpLDJ7p',
#  '0TwWRCufcJ2JVNoy3Sbxq9',
#  '226Yan8AY9FB1r6EBeoxQo',
#  '0DrqaJsKxKbrHCQL5et4eA',
#  '25H9cp6TqNJsO4an5gElNE',
#  '4mshYsCx6R9lnsBx9yuY1n',
#  '1ECWA9YjLC2vcErYZu2kYX',
#  '5UAbuLFYzS69nQRav9EwJq',
#  '02uRToy7bttYcKCO3vIStA',
#  '746KcHdT2vDEZQ5abSo2zL',
#  '24a4e5LP5D2iiY1tRE9v9a',
#  '5sCTpGoSyHGYbsntZfygMy',
#  '4qw7xhiy8rWGDeffgSj7Ez',
#  '5YeJpVe8zv0HoCxHidqMFk',
#  '15cfRh9OspQfSfOoQ1Efnu',
#  '5iXsr2NMr0EnWobhvuCMxI',
#  '5WgOELT1kPGBVCHVHvzIHS',
#  '5VLPmRK82MufxLszWyFavA',
#  '6vSmbrcdlXDEkQ8VAHK4Nl',
#  '10TEiwkiKzgeLhgT84hD0s',
#  '1Dt8urgl1237ARKm5yF2FO',
#  '6ZVJHYS263dytHJ305YzW6',
#  '13vUvRNe4McNeqXzLBEFSR',
#  '6nek1Nin9q48AVZcWs9e9D',
#  '6kopmMZiyLmw7h66uXcXR7',
#  '2fQxE0jVrjNMT9oJAXtSJR',
#  '79z9QkhHePTFsSeVw9uyj0',
#  '7ouMYWpwJ422jRcDASZB7P',
#  '4wzt5Rrk3W98pHXAqutuJw',
#  '4qG3Um3jXlQnaQV1yVo3it',
#  '46qPfZshPjoitCKdKVD6k7',
#  '3WSyYBhLZRLbQo2tJgFvSR',
#  '7efTNoBgYZ3IsB8wpP1f7R',
#  '6AUYnTv5LXbWm2oHxN3QAw',
#  '7K2vo9oSUzFgmtIXNYegzP',
#  '2FiaRFs6gjyHeMkeXifg4x',
#  '7iOA86nwA7RF3GwMa93H0v',
#  '4kK1C8RAToUEDCzeHDDJ3r',
#  '1ZwDntATen2rdQxz03rtTe',
#  '5BITMVIbatbnwwIF9Rfgcy',
#  '4k4qvQSDrWHeKGtAPbJPYL',
#  '1pPxT2XRy40Z4pCXhgQU99',
#  '2takcwOaAZWiXQijPHIx7B',
#  '2SMn57cBVxoD4TArscpovk',
#  '6FBpIPlWYCQyXiJsmIDTOV',
#  '0zAbTI9UGhiIhgVasVuVoh',
#  '2Ka7kuUSHw9dgm0QOslLMR',
#  '4kTaZgz1hKjHO9lFOgmGYA',
#  '50AXdOg1O8p8OUMw8SzrfE',
#  '65QVpgBIutEZlpDCi6AH2F',
#  '5lmYpa6EaVAKAlwxMf7q5c',
#  '5E7eg8Q0BOTozh8a1a4xaB',
#  '4o8n3o4YLMJeCFWlFCNsxf',
#  '0n6vdeqzU0CEw2aLxhb0XY',
#  '7CY2sRtE1tSpQE9hebe44i',
#  '2zzd1o3NLUPt4nAEMdBDdA',
#  '7GfLiyTxxOMbHnZqbn5tWs',
#  '74Fg0CoarCiJiVhDQ9RfI4',
#  '7cYb2cRJH1vu5kHcRmfVQp',
#  '0wGoxi2aR6VcHrAk2NXpWA',
#  '3kH4yOrlBJPExCQgxJevKy',
#  '6SRqLYihsrF27gcj5Vlajj',
#  '74tbgmKa80O82nZVdQPKCe',
#  '2Bh1BQCRXXnSZ6WKFBG7CS',
#  '5QCc2zwpyggLS8DwdTKWb8',
#  '3iALSfsgC7OUTel9f2Ohqh',
#  '2ycqZXMuSOUoVdIC5ZbRaG',
#  '6oOgAtLgehK6OarIVvnRjv',
#  '3BhF3fjSjEfMjJHvK6H8en',
#  '0sKLArvIMlZNhxEeS0Dg5Q',
#  '1LKNB3N8vVoxV9Tlh2KZqL',
#  '1eCQQvMLV1IGRSCrVj53KI',
#  '2ozMcZH0FH7lMAh9B7umRW',
#  '2X6a8h3Olet7EZD9KCvmqV',
#  '4Id59B6VCkhnbMJVae1uAp',
#  '38VdcBcQjWjGzb97E1gXlr',
#  '4KWXMI7fnMAj0tH33H3RdY',
#  '0joeSD3Tb9INp6w14e53ZC',
#  '6GGGdLWUS4jvZvhSXylxuI',
#  '0X2Tm7O7aG3ZkHjDucqAcw',
#  '3YWdxdMwTK3yiqubQixDBt',
#  '3V28a82KbwnWH9BrUIMxuY',
#  '5MuNxNox3zTanAFIO5KcTl',
#  '0D6qZlc6vNR7PDW2RKGPsV',
#  '3KkZ41mVEVQrdNTOv6xh08',
#  '4a2VdX9fRz3mFuEP17TnEn',
#  '1cBMPX3f3O1pTCaAdLNQL4',
#  '7N1Oss5OE1PS3qjd6qseKc',
#  '5Fm1I0XoPmyyQ5GB370e9W',
#  '2owzh9DY13qz780J83EezE',
#  '1TEvKR9jaAjfiTW5wEzcoe',
#  '7mi59PwfBafoH1pmbVkfp0',
#  '20gFQeaikLa2Ntag4ohjNn',
#  '1EsMJkbO5pMD1XDbuvEiv3',
#  '1tnHsVeArIFRpzQvFchZCt',
#  '3lzzAHJwHjSpA71ftgzDeX',
#  '5YnC6mEPD822KrmmlBM6VA',
#  '0Ftu7f2AJJrKFwlU4t7XRt',
#  '2jh5lZFuyMkGrKEepntF5y',
#  '6MoMGNgl3vDKZ3IQaHUvjr',
#  '6hGysJfPg591z5fqvTYL8O',
#  '2oCYH1y2kyvgfwBzJqebxd',
#  '1rcF7Pbe9uDmrwa4Sbdns2',
#  '7CEpyUJCPWzIzqReJjsGFm',
#  '083Z15SPMNvDyFVhtCzjop',
#  '4eayai01bYx0xFaNr606Nx',
#  '4ofFCOGsDjAMjwZZ8hgquD',
#  '5Els7kRz5dF7Y0NaaBVASS',
#  '5dPhdTPYQAi7Uz9YPuzNB0',
#  '1VqsDcSfKxLOF70BDWKTMV',
#  '31xfVJfEfvjqKChKF55SnN',
#  '7iyHZPlxuOBhQcHbw3TfDB',
#  '1gihuPhrLraKYrJMAEONyc',
#  '5IVuqXILoxVWvWEPm82Jxr',
#  '1EzrEOXmMH3G43AXT1y7pA',
#  '4iG2gAwKXsOcijVaVXzRPW',
#  '67awxiNHNyjMXhVgsHuIrs',
#  '5covTs92HnHJwAWrXF7l14',
#  '4C463MZrXGxq3t7A3wlGuV',
#  '7sMGwiS4vOMcz86ZY3vKYM',
#  '5WTxbyWTpoqhdxEN2szOnl',
#  '78EMhiyAcalWWtnpk20Eoo',
#  '63OHQ5zebkOIllF9O3372c',
#  '2FiceoWDJ67rrmb5tGBpgE',
#  '3Dupb5AcaVFErlSSfl3szW',
#  '2gNAGt7gUiMkagkhIiDLPm',
#  '5dl8WFCxndWZlsDXuzT00p',
#  '4nRGPCJzJDpalRLkpCqvD6',
#  '6PRC2qyslEy7GfzmtyDPQp',
#  '2l98ANVveepjqXIWaIoCDW',
#  '3NN3bw0UMt3DbFUVGh78kV',
#  '5pzSsipRTmu2tD9I3Nihxw',
#  '1vabQAO370qU6hTvzDGkQZ',
#  '0fuP0ykgrDSxk5odNU7Gy2',
#  '1r8Clr74LTo1zIHRqNdcFv',
#  '7LaUGKo8RjOjalzzfmgEY7',
#  '5zsYl9Nl4kQmPSjwscVASJ',
#  '3D6cttYfJAr3w4Q5gD8AmF',
#  '5tXyNhNcsnn7HbcABntOSf',
#  '46noql0WVyaOHoGeorSHh9',
#  '0xEIhF83JaaXLG0RPUViHJ',
#  '74Xz14Lv4wSetaPiLMpWzj',
#  '0I3q5fE6wg7LIfHGngUTnV',
#  '0BCPKOYdS2jbQ8iyB56Zns',
#  '4lLtanYk6tkMvooU0tWzG8',
#  '2hKdd3qO7cWr2Jo0Bcs0MA',
#  '2M9ro2krNb7nr7HSprkEgo',
#  '3ZffCQKLFLUvYM59XKLbVm',
#  '2dLLR6qlu5UJ5gk0dKz0h3',
#  '4eHbdreAnSOrDDsFfc4Fpm',
#  '6vrUTGn5p8IrfTZ0J6sIVM',
#  '12jjuxN1gxlm29cqL5M6MW',
#  '2MVwrvjmcdt4MsYYLCYMt8',
#  '6INLpBxo9F5QMer04VXEnd',
#  '6jizk5lOUnfpaZXYMdfeC6',
#  '6LtPIXlIzPOTF8vTecYjRe',
#  '5cwN1htZyoWqZCc33f3RfE',
#  '0agBriTy7L5vFjeFT4qXr9',
#  '1JqTcOjOn7gEpeC0JcRVPa',
#  '0HLWvLKQWpFdPhgk6ym58n',
#  '5VFzIzR8nACf9Bad4O73f6',
#  '6FjAGZp7c0Z2uaL3eHkXsx',
#  '2MQ51y5NhCyva4SgWmK2Me',
#  '1MUQ6LtYIw6sSGQJEoIi2X',
#  '5zF2zGPkL6Ipsn9AfAK6RP',
#  '3trS6e40JCVUOpPVt5OdHj',
#  '13qqdlSeF8FcxsRyapDMZ0',
#  '4w3zR0z2oqv8ijhOkTnRvT',
#  '2Oehrcv4Kov0SuIgWyQY9e',
#  '46bkeaB7DA45q7PdKWLFkR',
#  '6nmVeODcBpsGKx5RPv003D',
#  '5ve0BYRZZ2aoHFqZMxqYgt',
#  '7jSQaXLzpLHjSQTev2krvT',
#  '2SvULYdmPes23yZQYeLkXV',
#  '1oDAFTOXZGSQedBa6hXGhT',
#  '4P1sbofnneFeEEASTFMEGl',
#  '2Yjv7MOdst5y6fFsq4cKOL',
#  '1bA0ykot0FXsQZ2QYgErSD',
#  '5nsYZFNyMefd50yamWgMfy',
#  '3LNsyHdo8MWl4mqbkzAvKh',
#  '1LWabh9wqLITaRpYe82PoD',
#  '3iaolMs6LZvutK4RMNIPi8',
#  '0dBeZNIXFp3P5RnNQGEu2x',
#  '6s0M6NqA9YIWnsRPMKRsi3',
#  '44RRNCHX9oJqPxjyJlbSrV',
#  '6pJZ6ah8d9fQmZJrBB5JPL',
#  '2pxM1i3B5CpUZNTy8laF3h',
#  '06y8DoxhcukGlIChYmRWQ8',
#  '2wy3appX7CyXNSlEI2IH3X',
#  '3BO3R8SLyb9cfSCgk1kXUl',
#  '5h4bVElGkP6CryCHL8WMd8',
#  '2r2hR9gGMdusndlRzhM0cc',
#  '2yYXpmxUXWxcpc0b7oINEC',
#  '2W2d36UbMqfzhmufiInwJr',
#  '5PvjR65Uvf6nwBe0Ko9O7z',
#  '4ASJhgJdOEtAwqDp37YUzd',
#  '1wmmlJxCrOPfFO6o4gel78',
#  '0NvKyH2zVnhLcgMM7wAuK6',
#  '7rGmhrepNzP1LJhm1bSRDA',
#  '7pHdkCXkeC8AYHMcIDzUdf',
#  '1FycPgMDd5NkVV0zzbxGyN',
#  '4sm3tGqlJ0qMIUse4syKRI',
#  '0U0ldCRmgCqhVvD6ksG63j',
#  '1V4jC0vJ5525lEF1bFgPX2',
#  '483XiZ5o13Cc1zoWV7jGml',
#  '0UeYCHOETPfai02uskjJ3x',
#  '6jNM6fKx3WnyHbWBI9hs2r',
#  '7m3povhdMDLZwuEKak0l0n',
#  '0wLqXnCLseMice1Hwq6yLz',
#  '4rwpZEcnalkuhPyGkEdhu0',
#  '5WSL7UTa38jMWoBzObD4BD',
#  '1GC1MIaRMW3kfVK9VyD5Ii',
#  '59mrqUmhpmcfUns8BKkV30',
#  '0nejfXN5tjdICWIdfakXWx',
#  '7in46wlBseKBTcLi6lyhF9',
#  '5B80SdObHYOE6fxgvnbeMs',
#  '2fSiZWV4xHCHK7xlnPi6tj',
#  '77sVUchtzjpetfDZC9L59d',
#  '0lqNstW27BvhHXn6sqyQhX',
#  '5JEyMbmqdPeD7FlyLv3fGp',
#  '5NARCwodmWYJk1o9S7BLYs',
#  '5NK982GwMI332zcnpeqX5t',
#  '4RXpgGM7A4Hg7cFBoH5KyF',
#  '3ezkJgagRPZ39KCTrKcSI7',
#  '6OGRM4MAOlyOdhHuX0OJ6P',
#  '2OXK1ShksXD51tOLsE0E7s',
#  '3vI5AzbPh1HFDdGs1dDQeR',
#  '16SsiQFVS2ZyxqqF5OB7m8',
#  '5oPUBUzrAnwvlmMzl1VW7Y',
#  '4qPnE8jBZN3wmgGxspsOcP',
#  '6ZiDM5JM4nSyQm4qxsQdRG',
#  '75TZt74YXA1KOqgGAr4cSs',
#  '4nvgOOsVAilfa3xgku5fSE',
#  '6G1rjrxzPXBy9xHNksAX5b',
#  '2LeKFROk4McqRXRMy7YR96',
#  '16svQmHL0I0F3LcE8EDPg9',
#  '6jsxdPGKj6oO7FOpYxoCDE',
#  '1CKGB4kFQNGP2T2HXrZmov',
#  '6j0wDeTV0WKmmIXoLvjSs7',
#  '1EY6BhM80c2PsobqxKY5JW',
#  '6ba3H83IYgwYVnT3VZUxUM',
#  '36ArfC9UDgQwHwFMLUx8Eb',
#  '2WCNV7XBKv5P58Y7tprWF0',
#  '5jPV3O9mmO8eLbURAfAbGT',
#  '2GVbhbv8C6qASzGBrCSFX0',
#  '0x3OZdDNtycGZecouTLdbk',
#  '42mW8YfRXATwhNDBBv0UqH',
#  '2z9G4b9QjlwlCx2Pkwl6Lc',
#  '6yjoLviIwT6onwNdzCQrm7',
#  '71Na8M1MC7nOI98gd10V1F',
#  '6XGTmjk1bQgxGc3wjwPCvH',
#  '5wKeeypbrhTJnFhP4SGhIM',
#  '2jDKaPvf0I2hCENkw3AkQg',
#  '1sMlXguBgXKArge6SoW9pE',
#  '2cv00jzOvrS8zXcXzGEGQu',
#  '13C9d8slrZ2TwxwgoGPEVy',
#  '6tIfLRqGeg2MuXLuSICmg6',
#  '0jtIlxqj0dGEmzFgYZZtLF',
#  '6W4V7BiQv7hcVFQxDPVi78',
#  '5deJ93GGaHYD1IjdG0T8Pz',
#  '2WCe7XutBRavur2DJXV7TK',
#  '2rxQMGVafnNaRaXlRMWPde',
#  '0r8iDf65NHgFgZOGLwj5r8',
#  '5s7m2xNZWgz5FqVSIvJcGA',
#  '3dCZm5HrG0jIXAHfNkg2H0',
#  '34SQ0QfLSR316d8KL2zkuZ',
#  '0NLBwQBYJhEM9t3KAMPFVR',
#  '6Ymvlzom4TQeoKqAWsZRD8',
#  '4Pn0JlCUusD2QHjADuOzuV',
#  '0VU5k3vCrpqDgUygMjiFYj',
#  '5TWhLgjy8cgb6CRPnnlnn2',
#  '0H04yVa3DJxoXbLBpAb7iV',
#  '1zWZvrk13cL8Sl3VLeG57F',
#  '2d48mamATjby7wgPjdrSOQ',
#  '0oTGa77jJ1H5joTG5SvxFj',
#  '3wx2kQWPn9p5UppQbNhPAk',
#  '4PKPYaqznLL7PVwM6U3vWq',
#  '4wDxa0lo9PfPdnDifyCE6h',
#  '1Fo2N5iXRi37maMboaig7O',
#  '1co0puPTYvqAdUEjFOjne9',
#  '1CyanrHZ0R07Yp8Nwq92F6',
#  '2YMhrXQYKkm4kXLcXKKd5z',
#  '1XIYYgAkVxULMbhr2zNjKS',
#  '0TRt5XHzpJoI7nW2bJFgUC',
#  '7Iykxm9uV9n1Z9mKMc3N2h',
#  '60OYLqg97AaTov6Kd4VZFr',
#  '1Ov6koHfZL43pGCDdfIoHf',
#  '0AOMCsfuOaL4omgEOoM3DE',
#  '4dGJf1SER1T6ooX46vwzRB',
#  '59fi7eaSe4DuCqfua35m2W',
#  '6aNwDe5YH5YUPlpHkku52w',
#  '60wwxj6Dd9NJlirf84wr2c',
#  '1pKYYY0dkg23sQQXi0Q5zN',
#  '1KtD0xaLAikgIt5tPbteZQ',
#  '4zu9wo2FXoBSsKjO6tRB3R',
#  '7foafyqmJYUdhGBpIusueW',
#  '18KDpXD6e2UGRA5ORND1CU',
#  '2Yhw5UiH13rDTGCeWfzK3n',
#  '152kYn6HxbRSWBlkkZHWGN',
#  '6ZZ3cQvx4KvbdT4mBRG5Yq',
#  '15kdGzJcLr8TgxQVMy3sP1',
#  '7wQRAgTnBowC3myTLJSSNK',
#  '1rDeMLugWYVNwZXdwd4hI3',
#  '3c79AfWNOTCGTKWlIRnqry',
#  '75oHZYDpJQdnsOh2eoNZ3g',
#  '5Dvb8wNsBfF2mCrhGGfq1z',
#  '3ijwgHEI1JnYVZWZoT0844',
#  '4QqlfK1yqd8A4hykzkqSIA',
#  '3Hepksq7EjajtMS3VA9qIN',
#  '5gUhWFZCwtxk78xGfAluBQ',
#  '6Sr8JkH7XRVk7Dnar9Xsr5',
#  '516V4vS25xnGdVgkBWO6Wf',
#  '1LQiF6aZfnNgxerxWJRbxw',
#  '6onDLkVuF56CMtaVYGoI0Y',
#  '6rEc69BeR8xHy3kN1ZFCsX',
#  '4vS8VaBwJJV5Ry7UFIQuoo',
#  '1y8D3jABt2utdhbcMn9eWj',
#  '59m7BGTgtRQBHrUlu8lC34',
#  '4LUu3bMpuxHjwPLj84rNSx',
#  '4lnsdLzmeSf57R94syFvJj',
#  '3yYSeOJRqJncyMNLtUMJt2',
#  '4uOKFydzAejjSFqYbv1XPt',
#  '1jqLJBQwo7yBCqYQWukLkq',
#  '6YvP6BkFG912BHoq7ZNrLD',
#  '5AoswEmlPPrhAoErCm0Y0Y',
#  '2LibQBigAh1Mf3jWHKgZcP',
#  '4G0M5rMRmERVLpwC5K0YDK',
#  '5mjHJx2xQe679j9dSnqeHR',
#  '1Ra8d6lTOlEb6KvDFbi7dC',
#  '0cYi2oZKIxhJxR2rW6lt5o',
#  '3k2tb8a1Xms7Lp7OoY7fUv',
#  '0oQr4G8dxa0mSvfJDpIaZS',
#  '32ryIljZU31wGhQqnYmEAA',
#  '4UuE6X73ULJZcZeSCyntMI',
#  '4zKx2Gdsbd8s07BfMjClAB',
#  '5m2C9yTXkC2yzoFJMPmgyX',
#  '4tOeiJqj6vhXjkckN6T3X5',
#  '54rCkxZ4cHJb3H8RijWmcp',
#  '2o2NqATSotAowi53RN0lyj',
#  '4uoB98OgGSQxivY4EyFyWd',
#  '4BsfpiPJJ6bp4tEFdf3fN5',
#  '1q7s0ldnDXPSYlPWgGkcRH',
#  '7k8uO5gg1ya9fPMynCuwpt',
#  '7mtR5jAkzwouXkH49dzgG7',
#  '141UaTkN81q1UKSzLQzssY',
#  '507Km744pKo38jLyu0Larq',
#  '3k1ShfDeUnoL28FYTXtb4H',
#  '35iDOurlfhwUZ7VIrKmOld',
#  '45Y5EshIZkNnE70nrColBB',
#  '7E4M2w01zZTpRk9JO7crQ5',
#  '3boIk89DUwHkIa7BstSkhA',
#  '4E6wpXABj8XosZEPXZz2OK',
#  '2gSUtqdBM4k39be9FzQjOH',
#  '4IfEHfXLyepX85MFehNHNd',
#  '4PHppm7v48ys7YrVelKSYq',
#  '78oF7KjxHMJHtiwgc2I3rw',
#  '1zA1xc9CxnJj1Wn5HlSq6k',
#  '6afniX7NoYXq4MfXNv1v8R',
#  '5TiDg5EpGO1jWpvn6dRK40',
#  '4WZuTswubOiMnVt1rlG6sL',
#  '4tYel4Nk1WVZ2mg2WUkBLS',
#  '53venLGYUkmARbtp3fAydg',
#  '4SXbZbMoKTaBAFcsbSkdc4',
#  '1JrkWtIhVG8Z05AQ42jv2E',
#  '0y0HtHL9ND473xMOsgacr6',
#  '1dTD9ENy22knq8T2lSB4Aa',
#  '0XJWTGozxcjZ9JmQ1xtuXc',
#  '4RAtUaWDQdBhDOBMBzUQD5',
#  '12qGKZwI1pkBYDpthPCmNY',
#  '2FsieECB6cTFKIculkHTgK',
#  '2KGH9mcrOpe678C5SzTmgM',
#  '26E1JSa1rmqadkaMgxeTDN',
#  '61pIREEN47HGiCd1uaKGW3',
#  '7dnkxRxRnkNRUWaY6azFCp',
#  '1IDHO8KkIylw9Uv8Md38vO',
#  '6Jl6Ry8yWdHmGB5RoNPkwG',
#  '5EV2tjBxXxTqJC1fKXzr7j',
#  '0PHfaAsdvaQ3o7PlvxP1kA',
#  '5B1wDrbvdJdocWJDOf0t5x',
#  '0HWmdAs21fDHZUI0fDgiHS',
#  '12Y73AQEjYzhQp6lRLzyLq',
#  '4kdjHU5lzooUP7kkzQqX0Q',
#  '7hrDA2n8BVGLyHra0rBiFd',
#  '1kDqntrhTIOeFyuQAJfTs0',
#  '6hH8CpyufV9n8ELJ6SIKhn',
#  '2TbcefZkF8WYzQYoxHEpCq',
#  '2VxKNz6Bkader0Qcn4i1JB',
#  '7JO1eDSU1vnRTMubV330i4',
#  '5embwg62CWtnOXOgEoPJbd',
#  '7lE8A17Eo6DOidUbLjPD04',
#  '6ocWi01hGuVeJLbBeGwhNm',
#  '7j8rpn7ozddHA0Bj08q2Yo',
#  '1wap9wHVL6wzhmQOuyhwMH',
#  '3P2FUwhWp18EXMJQjuixRb',
#  '6z9rsYMMS1ZI9QaNZ5yEo5',
#  '39tZWuO0TDJQB7kk8c3mAm',
#  '1GenbpddqLK7tyHmVYubjJ',
#  '3YvmTh8Kgo4sT6JhrN1LkO',
#  '2IQOvayWaFrpkood7514QQ',
#  '1iN5zmmHCCKDbHt1zYwyt5',
#  '25TTCd3DUGqAk4jjHbYVdh',
#  '649xyonl2zr3Gj862rwU4X',
#  '4ftfnryuTPdsuyCiAZAcx8',
#  '77qMKFGYxGZewgRXdR8cbF',
#  '01yeTqxSO9FJvFm3hehiYe',
#  '20DLapd1cFKgF0kFcaF8Zd',
#  '7pJnM2aIuZQk9HVNnRnL86',
#  '2hXjRBkInMwEwBW7YUzP5x',
#  '2KluxKq5yTWYWNCdrOQNCr',
#  '6VWDf8yvbXTpk0YUpMfSBf',
#  '6gQH6cJuBPukbDb1xtWCVW',
#  '5sJiLlgQKBL81QCTOkoLB5',
#  '2Ktuc6919DC0C0hx1tXDQH',
#  '5aEBCOVqUReovhMm4rcuDf',
#  '6SUrgfIB3ZIHLj1m7ANi6O',
#  '4FvP0Ldfhouzs0togmtO4E',
#  '53IsGgRHpOwsk9FtiYw0p7',
#  '1K9rZwxQQIg5DszfBvcGGM',
#  '4mLW7WyoDiXLQsGMiGXyVP',
#  '5P02bu0noGwunRWeKQ5JLx',
#  '55cBTYWu5EoBqwP41ofN8Q',
#  '5Cn6erPSDitDZ7ETgECTZN',
#  '6vdtNDtjhtma9d8FU2w23A',
#  '1JSkmlzKf7nmdMA2i6HeTJ',
#  '2Osc47wOpsYRuLTFtQsYnt',
#  '59ZGaV9GEkogUjGvhCe21V',
#  '39VfFItzZejusmAWWdyFZv',
#  '3ytKkLAncl7XYQ204UWOE6',
#  '2GqG2rAE5QLLlMTXU7Qmpr',
#  '5urzDQH35s0brwoP4y8yoJ',
#  '6bV0lrvZGHqitHxhTh6A0H',
#  '7lJfADxd6xiSHYnHrRYkst',
#  '0BoO7pz0c9xVazV8nW1l2T',
#  '1h7r1KcWPPpPIAUpJZ6dwl',
#  '1sY2ywGsBF6mQmi8DMdjB4',
#  '0tzbzg555XQdj6oTj8g4w9',
#  '5y7lj47TqLBRwS1JxmXWjQ',
#  '5qQ5GqomeoFjFLoM48qJek',
#  '6GWSWT6DhJRxJDNAzLAsGC',
#  '1hUnLQ8hJV1oVVOsAcKVyk',
#  '7wEjgG7iWBaVXJs4047RCn',
#  '5rb9QrpfcKFHM1EUbSIurX',
#  '55h7vJchibLdUkxdlX3fK7',
#  '3bidbhpOYeV4knp8AIu8Xn',
#  '3XIEWK1V9n25PS9Vb6axj5',
#  '5IKLwqBQG6KU6MP2zP80Nu',
#  '41KPpw0EZCytxNkmEMJVgr',
#  '0u2CGItUO2jYEiFaXD7n5S',
#  '0kPeymTUiaidv48eRrMISu',
#  '0PCRR19Pf4iiuvSrPxtQ0x',
#  '48C219M8L2HGsFTLudljk5',
#  '4PQA5I8Qf99He3SBKtl4Tf',
#  '6mwZS6fLcQP1wKv3HN3OcY',
#  '209NkbzmsUa9pAobU7xGyf',
#  '20pPweU5sbfOOB1Qk5KCTx',
#  '6rrUcrhWlW3CqGYT0zxYlz',
#  '7K09L0XlSGoRM8v8V6aXZ9',
#  '07MHhfYd2Kkt2zFnqRZM1z',
#  '4wZOmbYApgoF2zD9IHznDD',
#  '11fGpV4GpQELQqSv96DBeA',
#  '6NPVjNh8Jhru9xOmyQigds',
#  '6sh2gkdFAxmDEIwtLRrJyR',
#  '4HXwANiIbYQvwDTcLXiacY',
#  '6hDH3YWFdcUNQjubYztIsG',
#  '5BfleIMgLlfeqG5yqKyHz0',
#  '4jx64GUcjOIKl6Rdc0gXRB',
#  '6WfDlkxh3cFinLzRX8A2nP',
#  '3CMBcPY38gVQjsp6V2fvvn',
#  '6aGjEZ7kq3YXgD0EDt80O5',
#  '5k3U0OGYBccHdKJJu3HrUN',
#  '4VCexsNDyC2j8ZrY34RwV0',
#  '3sT37kCEpxM1zQ8s98i7ps',
#  '7sKChFvViJZ6FzQZwCuPqZ',
#  '79oesFYaS2VT39ShdA19u9',
#  '3oFSbVCS8conK9GwJWOSH6',
#  '7r6ubHsaieaig4kORmmsDy',
#  '5QsEvml3ZEnISKBEaKueUy',
#  '01sOUDhgCz6cNoghrnO8bG',
#  '5zhBhWQcHsvycF83yvIAzC',
#  '0UD7ys0dd5SWs1g93ZzfNs',
#  '0wWFJ3wMSK5wXLuNR1csPQ',
#  '3h4hTUf64pVgBYufYdeeht',
#  '0e9yNhxYfJul6sQ8Cizr1B',
#  '7JIvgoalTwUz528BVYXBto',
#  '05E73gk08h7ECa4RjvcYwB',
#  '68BT9XvXmCWbMAtjH9LT27',
#  '2LM7Oyo7SQqmIYjxkONhRe',
#  '2AuTF7yXMDPhBHYBLjWcqg',
#  '16B444Uk3QW6B1ikqbQZ2I',
#  '0G71WvIkF2K6HViJeFvOcM',
#  '7aSsgR6CN8AU470gocESkw',
#  '5xCwjnZ6BRHFb839eAXGru',
#  '4OlskbEVBi1jpQKBbKHbm9',
#  '3AGVMZ3S9ou3ymWwBnqDtQ',
#  '464YC2e67DJOXfjLxCBKde',
#  '5foJ5ubEoLwJTY3RW0I3t6',
#  '3Y4GJ1fC9YDlgi13y2wpO7',
#  '3Uqw19tA28XgrOE9Ml5TXP',
#  '5WZ9WgwWPlPNt5FNFAFvkd',
#  '666elemQTQGi8xbjAAdIgB',
#  '3VPBqHUd17ZvEgabW9ZOUU',
#  '2A4Ij58MiGtsYOHBAJ8Wph',
#  '1POpzXwi5LRsjwWO9sgRAj',
#  '2RuBAvgCePBw6YuTOfvLMZ',
#  '5gHMAfnMIJzi2s3SiVeWiq',
#  '4YlAdZBuW5mww5GcqZ4aFy',
#  '6UXvye1stGPqosVdj9R8mm',
#  '0ZcR8LX5cGLxr2v93WUIFO',
#  '2XRVX8Gs5t3ofmMqyF9pqv',
#  '4InW9ynMS1aTIeFSMvHjD7',
#  '2RnJ0n6YEPyzQzknUrOb7i',
#  '4SqSynbqLQnR3wJbdB7w1m',
#  '2JK083CksL35hs6SRfMdVv',
#  '2xLEurbAPdnetOaMHKlvC5',
#  '0OS7gsqsYZvFYjYM6SgZMk',
#  '6jngF5xJrRvo2tmRPrDVoI',
#  '6uoajL6rGG8id4AVbKtwqu',
#  '4tDI4RmuOMdvuENHkkBMAw',
#  '74uiiVGp7ziVpB2ofv64l6',
#  '6kSjTqaANVl7eyCYK1mbla',
#  '0lwSGq8WP6QpmERRpWOqjQ',
#  '34P1Oyl7hvYQwIVmY41F61',
#  '0CG7zGdkTjoTRON8VHLtzT',
#  '1SEPNX4M86N7skvm2e2Rhb',
#  '62PdGwG6Hv8sCyd29ExKEq',
#  '7IidFOieIlIMrSOgVTC5H7',
#  '4PqkEUE3QXM88CdtyeHOhW',
#  '2jwuaUinaZuE8HkLcpylsE',
#  '3WHlzAecQsOU8vkbUUrw9s',
#  '25EgA1A1OZBRw25Mjyw08g',
#  '6qpaTfe6rCl55xEPT4F7Hp',
#  '3IBMJLY5uN014W1hTzdTRl',
#  '5crHvEPQ13FbQGQSscm5Ns',
#  '4SMciQoW2tOVieBAg6U2Qj',
#  '4jIzCryeLdBgE671gdQ6QD',
#  '6HNGXmc7A14zeeWTj4gzz8',
#  '73LjHkIsz1EcT9bn8z0cRU',
#  '1FjFL9rxg2nkmAkrHuhlYc',
#  '2MlcK8OgC5IpQz3l093YSR',
#  '4KzFap4SNIx9D0LZzR1pNd',
#  '0bFu1acVz49Y65ll0Fjred',
#  '75bLgr2GCd1I77vLxqfU0w',
#  '4DqvFOvWWRCqCwyNqvHuAv',
#  '5BRrBkpj0An7PViNqMCoGa',
#  '34o2xJAVNTzoYN0o2Sd6sW',
#  '5oA1B4mKMxeXH7P5enV4sG',
#  '2ogdppwwpZ7v1PUpVgTg3l',
#  '3Ifx6lCMbrjZbAAUnGhlpV',
#  '1zLhqXAXNSG7Izu9VRyMl1',
#  '0iwRfGS1mHKudbP9RWcIMp',
#  '6bDGtvTMJEMuCG2f8rlVp2',
#  '0VUBOOg6RIj6wnd2lSzGTR',
#  '27Uz9gSMNzDRhwtgUvy5V8',
#  '1ts1zPbYEXIM97Kc83rby0',
#  '388fpd0phQZZ0tRt7le5La',
#  '1KNWLV6YchpDzqxkrb7AnC',
#  '6phWVUn5CCTCRBepIKnf6D',
#  '4ce29VAx1D8f3HULOHHA3K',
#  '1A3XPibNuMPTbTWlPgRfTD',
#  '1DZfcSkibPHM9h8lPFT7LT',
#  '5s8LCFUR7tI8m4yNSUxwMi',
#  '1OL5hl7ECHguWiSiRCU1gY',
#  '2uM8EuKY4FjY8n2JcENJfM',
#  '6BYaK26CXx2Lg8gUENd6oO',
#  '0g6s1NJOe3Z1ADDPTVhaax',
#  '2R3FLUIbM7bADnHOAM9EGF',
#  '3NplPunkhgoMpYuNJxbPpJ',
#  '3VXwt1ijqDzuYo9Xho8tBx',
#  '4z9Eob4C20jeb1LwLv2sCF',
#  '4D4vEbWWVqW1FI46vTBBqd',
#  '2sIrBYQUmCxxhdZD5L0SCA',
#  '6JcgT1cZTxeYSerShMCkgb',
#  '5l6tv2lFylSdCgkWyfHC0P',
#  '5m68AfdNSNNC4quow2BPaw',
#  '3Z0eRV84fbHY2dStRU6l8b',
#  '7bac61bG6EVbOt3IqDa4SA',
#  '4wLd2PCLgMIS26vdWFwrlt',
#  '1FgbslUrD0hTVw0usa4YLs',
#  '20k9otzKdPr3wG9lU1w0kj',
#  '0Fvhxj0hsS1ECNV1A8llrA',
#  '76GUOMKAbAnVliU40wM534',
#  '4N7fGlnzTJLRiyt3g9JhYx',
#  '5FvFP7Ixbczk3pMd1yBx05',
#  '4aIvvv0oATCUPuBiDTIRfm',
#  '0GSU6yLOJqO10ziQuBLWOE',
#  '5Nn2Dj7OQsGL6pgQ9iIzPp',
#  '6lbhkPbkKj6jnPTt1FelVo',
#  '6I9sncEmtGc9rpKyb8U1f8',
#  '48n92l7OnLEURhalUBtsl7',
#  '0DanGj9TtgZIjJnHdTbW9v',
#  '2L7plRhGDguuuM9J1u5R7x',
#  '5Uo7AAr2d1CNZlaKgVUT3i',
#  '3bXptsvAsA4gLaaRKMHsr0',
#  '30sHxvIflGaWj7nnd3oSTo',
#  '2u0SSpdM9XNfzWAwoJWxzF',
#  '5kC6r4q71XMzsuLAYesseb',
#  '6j4PC0PT4A5TI9QitUTV2x',
#  '42prDRVUOkgzQsfSFL2mmL',
#  '6ZmjleAm3EZNC0HeC0XaYL',
#  '1elKl1ciiw49uTFZ4CTbEs',
#  '3QVteHLWhYhBWe7cX2fgev',
#  '0I7ouoTZnPY76XWsnHuJkl',
#  '15KHOhZTNh7bGogTgLNTZh',
#  '6WaBSLUShG3BpQUpXr0CVR',
#  '5ZrrXIYTvjXPKVQMjqaumR',
#  '3RWnOQTAOOvkoe02KIS9dP',
#  '6u8on7c8MPZQ0cXW70qlM8',
#  '4ZHNGs3LJODcWrU197iiwY',
#  '1BU4p95YjXuvCCRscALuxv',
#  '0JFwZZHhfRhEgwCVOY8MFQ',
#  '0cDtZgxBNJBmupoz5v84V6',
#  '0OwW9dj25kMLx7D4ZJCURJ',
#  '6PtXobrqImYfnpIxNsJApa',
#  '5snyhxAh55A2wlNRH7VVZJ',
#  '7B1Dl3tXqySkB8OPEwVvSu',
#  '3kb38wezoUA8ki5jPYy3t5',
#  '1E8S3CSv20KrKT0C1yAjkO',
#  '4yOn1TEcfsKHUJCL2h1r8I',
#  '3yitiXJG14YtXXPFVoNvb1',
#  '3XThyUoEI8BPDjdu954Uof',
#  '6c9EGVj5CaOeoKd9ecMW1U',
#  '6hgBJPTHoDJyxydmtFWHKf',
#  '3Ons6C3wXBMi8nYpLBMlVe',
#  '4IWLawtdMznqdOnbOR9cWW',
#  '5bgYTzUDzerRFN7fp86MkQ',
#  '6MVXdWtPSNMlpn7BuGtCWD',
#  '4tdgjFQSFO0KLBcOhuhUn7',
#  '71c5Jb38fgukgKSCGL6zpt',
#  '0FgfmsHUeWpOiHIcddnxF8',
#  '4Yr5qe66FardIDoGVSy6dU',
#  '6iBzUjscIAeQ2vKV67UuZM',
#  '6vkoFgpGHnQ9mwbZCY2yDh',
#  '4aJgRbquxdUaU0xEIMQpvs',
#  '4EoIvIihHfwyxnc2LkMtOh',
#  '4yQpMgnJSWXdjrZr8B8XZz',
#  '6Mte3fuxLakjlwD8b5OTLK',
#  '03fAVei89vxfO70FuLMrfc',
#  '2b712q3E27nyW6LGsZxr0y',
#  '2LeF2hl1xpBpPyjvv52rPl',
#  '0XzkemXSiXJa7VgDFPfU4S',
#  '0TDLuuLlV54CkRRUOahJb4',
#  '4ua0IepBEISCWwF8dTJvcU',
#  '2zBXZY8lvzzmtzm07uImXc',
#  '043vxbUHxQErHDIe7zuC0O',
#  '3aiycOKS6P30BnR7dUfrnA',
#  '2aUDpZRSit5Zg2R6L5r6dW',
#  '5osHRqrBmK2Am2FhoNm2FL',
#  '7wL42r11vcEhohThbDVz7Y',
#  '3ONL7uf1GN8FewlmIjy1uv',
#  '1KE3QtMWpWvam8IaawEKZ7',
#  '71FFYHirREB8bTCdcVVCLQ',
#  '3U5aILXwgt4VrTr1ta1AAm',
#  '2pdEafpOw3Jvddrm2by0NR',
#  '5zG4pMcM2QILFOFL3Y3ZMf',
#  '19mZZ1RIVf7lB6DgDAEEVN',
#  '1fc12F23NDBAN1Y75GEc1v',
#  '6oLsXoOpnhrvFMtO7H9L1f',
#  '0lDLDCow2G0L3fBlwMrXdD',
#  '1p9jcxaGI4jxas9w4LRKwN',
#  '7rMDJcIwnUQLpem0YxeFPm',
#  '3SZ7gFfFVEwW9jfggcSPWi',
#  '61fdvfO4VmZfkZe5I6lYAW',
#  '02daNfXTqmA4oiO3IoKkU2',
#  '5xEM5hIgJ1jjgcEBfpkt2F',
#  ...]

# %%
chunk_size = 100
#Here comes the code that chops the large list into smaller lists of 100 ids each
songs_ids_chopped = [list_of_songs_id[i:i+chunk_size] for i in range(0,len(list_of_songs_id), 100)]
len(songs_ids_chopped)
# Out:
# 36

# %%
af_list = []
for i in songs_ids_chopped:
    af_list.extend(sp.audio_features(i))
afeatures_df = pd.DataFrame(af_list)
afeatures_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.635   0.239    4   -13.924     0       0.0434        0.1920
# 1            0.457   0.757    1    -5.177     1       0.0320        0.0206
# 2            0.412   0.749    2    -4.657     1       0.0404        0.0286
# 3            0.585   0.266   10   -14.692     1       0.0271        0.6490
# 4            0.741   0.319    0    -9.245     1       0.0296        0.2470
# ...            ...     ...  ...       ...   ...          ...           ...
# 3558         0.207   0.834    6    -5.566     0       0.1230        0.8040
# 3559         0.551   0.810    2    -8.093     0       0.0427        0.5130
# 3560         0.712   0.444    9   -11.533     1       0.0365        0.6600
# 3561         0.591   0.422    7   -13.389     0       0.0409        0.6180
# 3562         0.429   0.415    0   -14.997     1       0.0496        0.7900
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1300   0.0724   62.466  audio_features
# 1             0.000000    0.1460   0.4170  102.961  audio_features
# 2             0.000000    0.0726   0.2640  136.019  audio_features
# 3             0.005540    0.0903   0.3660   93.009  audio_features
# 4             0.000000    0.1050   0.1770  100.006  audio_features
# ...                ...       ...      ...      ...             ...
# 3558          0.023200    0.1130   0.4030   80.037  audio_features
# 3559          0.000023    0.0888   0.9380  156.642  audio_features
# 3560          0.000926    0.0834   0.6260  118.548  audio_features
# 3561          0.952000    0.2180   0.6730   81.002  audio_features
# 3562          0.899000    0.1020   0.9650  140.554  audio_features
#
#                           id                                   uri  \
# 0     4JjPLqECP5E48MXcEc2wzA  spotify:track:4JjPLqECP5E48MXcEc2wzA
# 1     2ihCaVdNZmnHZWt0fvAM7B  spotify:track:2ihCaVdNZmnHZWt0fvAM7B
# 2     37928J06bQreiIuhZvRlWQ  spotify:track:37928J06bQreiIuhZvRlWQ
# 3     6ERQqdIkr7Rp4tt52Eep6r  spotify:track:6ERQqdIkr7Rp4tt52Eep6r
# 4     6WVtfUA8r0iYmQotCRVp2J  spotify:track:6WVtfUA8r0iYmQotCRVp2J
# ...                      ...                                   ...
# 3558  7tKHQy1vQGRHL9mIt5biX3  spotify:track:7tKHQy1vQGRHL9mIt5biX3
# 3559  6ooW7AxiD8FRyIBwVFKC6X  spotify:track:6ooW7AxiD8FRyIBwVFKC6X
# 3560  1qetiiwkJuzkL91TnzBJ9R  spotify:track:1qetiiwkJuzkL91TnzBJ9R
# 3561  7FIKMHuZDDlAx0j8wccvFj  spotify:track:7FIKMHuZDDlAx0j8wccvFj
# 3562  6O3cgvwRrl0Nv48diMuelA  spotify:track:6O3cgvwRrl0Nv48diMuelA
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4JjPLqECP5E4...
# 1     https://api.spotify.com/v1/tracks/2ihCaVdNZmnH...
# 2     https://api.spotify.com/v1/tracks/37928J06bQre...
# 3     https://api.spotify.com/v1/tracks/6ERQqdIkr7Rp...
# 4     https://api.spotify.com/v1/tracks/6WVtfUA8r0iY...
# ...                                                 ...
# 3558  https://api.spotify.com/v1/tracks/7tKHQy1vQGRH...
# 3559  https://api.spotify.com/v1/tracks/6ooW7AxiD8FR...
# 3560  https://api.spotify.com/v1/tracks/1qetiiwkJuzk...
# 3561  https://api.spotify.com/v1/tracks/7FIKMHuZDDlA...
# 3562  https://api.spotify.com/v1/tracks/6O3cgvwRrl0N...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4JjP...       193840
# 1     https://api.spotify.com/v1/audio-analysis/2ihC...       266600
# 2     https://api.spotify.com/v1/audio-analysis/3792...       263867
# 3     https://api.spotify.com/v1/audio-analysis/6ERQ...       281093
# 4     https://api.spotify.com/v1/audio-analysis/6WVt...       238627
# ...                                                 ...          ...
# 3558  https://api.spotify.com/v1/audio-analysis/7tKH...       238293
# 3559  https://api.spotify.com/v1/audio-analysis/6ooW...       325627
# 3560  https://api.spotify.com/v1/audio-analysis/1qet...       336187
# 3561  https://api.spotify.com/v1/audio-analysis/7FIK...       254027
# 3562  https://api.spotify.com/v1/audio-analysis/6O3c...       156933
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3558               4
# 3559               4
# 3560               3
# 3561               4
# 3562               3
#
# [3563 rows x 18 columns]

# %%
afeatures_df['id'].value_counts() # no duplicates
# Out:
# id
# 4JjPLqECP5E48MXcEc2wzA    1
# 2LiMbz4TXnxq2zVkMfDHAz    1
# 2jzlBSKI8GLq3pxlXLMwG6    1
# 3NBqqhwCfpg4kl2huq0LuH    1
# 5mwv60DUr15t4IhDX6FDyV    1
#                          ..
# 6wWyLpO8HbBYpKJR8C7Kml    1
# 425JS2NA2ZeAVTAUDfwhcg    1
# 6TGRZBZdDVimF8tmKrvTzI    1
# 3QDdUv3PNaES1pyoMScELy    1
# 6O3cgvwRrl0Nv48diMuelA    1
# Name: count, Length: 3563, dtype: int64

# %%
energy_set = {
    afeatures_df.loc[afeatures_df['energy'] == song_energy, 'id'].iloc[0]
    for song_energy in afeatures_df['energy']
    if song_energy > 0.99
}
energy_list = list(energy_set)
len(energy_list)
# Out:
# 10

# %%
for i in energy_list:
    print(songs_df[songs_df['id'] == i])
# Out:
#                          id                          name    artist  \
# 193  5yjh3L50uTieKFyvIc9ioc  Deathcrush - Live in Leipzig  [Mayhem]
#
#            genre  popularity
# 193  black-metal           0
#                          id               name        artist        genre  \
# 205  65ctx4YGWEn3QDYrxSSAoo  Across the Vacuum  [Darkthrone]  black-metal
#
#      popularity
# 205           0
#                          id   name       artist        genre  popularity
# 687  4E6wpXABj8XosZEPXZz2OK  Bleed  [Meshuggah]  death-metal          55
#                          id        name       artist        genre  popularity
# 688  2gSUtqdBM4k39be9FzQjOH  Combustion  [Meshuggah]  death-metal          45
#                           id         name            artist      genre  \
# 1264  33NLxS6mNVRf1GgezVIQMp  Dead Inside  [Insect Warfare]  grindcore
#
#       popularity
# 1264          21
#                          id     name   artist  genre  popularity
# 157  4xvfH6Gl07mbwK0lCjt8lD  ミライノナマエ  [i☆Ris]  anime           7
#                          id             name           artist  genre  \
# 174  4gJrYv7pMjwvYeVxxVtOqg  KIRA-KIRAしましょう?  [秋月マキシ(CV:芹澤優)]  anime
#
#      popularity
# 174           1
#                          id   name       artist        genre  popularity
# 690  4PHppm7v48ys7YrVelKSYq  ObZen  [Meshuggah]  death-metal          43
#                          id                    name       artist        genre  \
# 184  18NypWmoW8PMQCcfWUV913  Repined Bastard Nation  [Satyricon]  black-metal
#
#      popularity
# 184          21
#                          id      name               artist        genre  \
# 105  2aCsRmHTuWPL7WnL5uSijc  Miss You  [Foster The People]  alternative
#
#      popularity
# 105          44

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')
